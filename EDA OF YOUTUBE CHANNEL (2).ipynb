# %%
api_key='AIzaSyCPGmr3RjVWoabbkZNum8QO-2YpUbEAs7w'

# %%
channel_ids = ['UCYfl5C79vyKVi_c58aySWkg',#fashion
               'UCdki4WC-kozzkFVoljzXQfA',#fashion
               'UCguUR7CobZWf3n6enaEGZqA',#fashion
               'UC1igBt6N8ykui8AXLOgtgMA',#fashion
               'UCuANNZg512Wvf-I_AMwZXnw',#fashion
                'UCfLuT3JwLx8rvHjHfTymekw', #roaster
               'UCPtPyb4VvaNqjkbL_tSVFVA ', #roaster
               'UC0rE2qq81of4fojo-KhO5rg',#roaster
               'UCdJWSUcim5IfrGW-f0RPPlQ' ,#roaster
               'UCAov2BBv1ZJav0c_yHEciAw',#roaster
                'UCuHdudvM214T2iouH94kN7w',#education
                'UCiGyWN6DEbnj2alu7iapuKQ',#education
               'UCeVMnSShP_Iviwkknt83cww',#education
               'UC510QYlOlKNyhy_zdQxnGYw',#education
                'UCExx109KH5msQR0n52ZzyAw',#education
                'UCKVei70N69V3V5wBQixHZbg',#gaming
               'UC5c9VlYTSvBSCaoMu_GI6gQ',#gaming
                'UC-lHJZR3Gqxm24_Vd_AJ5Yw',#gaming
               'UCx6F-rETGiz7xf_vkMmX2yQ',#gaming
               'UC2tsySbe9TNrI-xh2lximHA',#gaming
               'UCsDTy8jvHcwMvSZf_JGi-FA',#politics
               'UCloWBBZ3E9b9NGW3r30DN5A',#politics
               'UCQlshr3xpvpcCeAZvGRz9Zg',#politics
               'UCRgMIwmmh1-2k5HeTQ2cdkQ',#politics
                 'UCs0kMbzhUYV2lhIV7xoWhoA',#politics
                'UCXsXitjiT_8qPgNEFGPVfBA',#tech
                'UCrkP7L7oieiejXdQHWLqYIg',#tech
                'UCdoDYkupTElV62K7ttA_E4w',#tech
                'UCdp6GUwjKscp5ST4M4WgIpw',#tech
              ]

# %%
from googleapiclient.discovery import build
from dateutil import parser
import pandas as pd
from IPython.display import JSON

# %%
api_service_name = "youtube"
api_version = "v3"
   

    # Get credentials and create an API client

youtube = build(
        api_service_name, api_version, developerKey=api_key)

# %%
def get_channel_stats(youtube, channel_ids):

    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute() 
    
    for i in range(len(response['items'])):
        data = dict(channelName = response['items'][i]['snippet']['title'],
                    subscribers = response['items'][i]['statistics']['subscriberCount'],
                    views = response['items'][i]['statistics']['viewCount'],
                    totalVideos = response['items'][i]['statistics']['videoCount'],
                    playlistId = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return pd.DataFrame(all_data)

# %%
channel_data = get_channel_stats(youtube, channel_ids)

# %%
channel_data
# Out:
#                       channelName subscribers        views totalVideos  \
# 0                  Shivam Trivedi     1180000    161458890         342
# 1                     Tanmay Bhat     4700000   1454221567         995
# 2                       TechWiser     2070000    506834345        1081
# 3                   Gaurav Thakur     5960000   1040144296         769
# 4                      Manoj Saru     8220000   2127388050         316
# 5   Physics Wallah - Alakh Pandey    11800000   2380577399        1537
# 6                   CodeWithHarry     5770000    731139879        2336
# 7                 Deepti Lakhwani       29300      7919813         768
# 8            shreeman legend live     2080000    440252232        2414
# 9                  Simple History     4720000   1433383009         946
# 10                  Rock 'N Learn     2320000    684358450         587
# 11                        Mythpat    14500000   3329517378         388
# 12                    Samay Raina     1310000    383706339         869
# 13                             A4    52400000  27258306691         885
# 14                      PewDiePie   111000000  29257705571        4757
# 15                  Abhipsa Joshi      146000     72599292         575
# 16                   Vidhi Rajput      107000     92016599         658
# 17               Engineer Reveals      319000     39570236         514
# 18                        TechBar     4720000   1219918663        1336
# 19                  Abhi and Niyu     5760000    859190443         810
# 20               Triggered Insaan    21500000   3854207690         331
# 21                           AKTK     1410000    258004585        1407
# 22                 Way to Success     1800000    144745297        1830
# 23               Gaurav Chaudhary     5110000    361256406         212
# 24           The Sham Sharma Show     1460000    349178311         918
# 25                  Mishti Pandey      937000    524308748         434
# 26                     Style&Dine      126000     36000204         886
# 27                        Thugesh     5470000    932852828         374
# 28                   Total Gaming    40400000   3993794259         489
#
#                   playlistId
# 0   UUdJWSUcim5IfrGW-f0RPPlQ
# 1   UU0rE2qq81of4fojo-KhO5rg
# 2   UUdp6GUwjKscp5ST4M4WgIpw
# 3   UURgMIwmmh1-2k5HeTQ2cdkQ
# 4   UUrkP7L7oieiejXdQHWLqYIg
# 5   UUiGyWN6DEbnj2alu7iapuKQ
# 6   UUeVMnSShP_Iviwkknt83cww
# 7   UU1igBt6N8ykui8AXLOgtgMA
# 8   UUKVei70N69V3V5wBQixHZbg
# 9   UU510QYlOlKNyhy_zdQxnGYw
# 10  UUExx109KH5msQR0n52ZzyAw
# 11  UUx6F-rETGiz7xf_vkMmX2yQ
# 12  UUAov2BBv1ZJav0c_yHEciAw
# 13  UU2tsySbe9TNrI-xh2lximHA
# 14  UU-lHJZR3Gqxm24_Vd_AJ5Yw
# 15  UUuANNZg512Wvf-I_AMwZXnw
# 16  UUYfl5C79vyKVi_c58aySWkg
# 17  UUQlshr3xpvpcCeAZvGRz9Zg
# 18  UUdoDYkupTElV62K7ttA_E4w
# 19  UUsDTy8jvHcwMvSZf_JGi-FA
# 20  UUfLuT3JwLx8rvHjHfTymekw
# 21  UUloWBBZ3E9b9NGW3r30DN5A
# 22  UUuHdudvM214T2iouH94kN7w
# 23  UUXsXitjiT_8qPgNEFGPVfBA
# 24  UUs0kMbzhUYV2lhIV7xoWhoA
# 25  UUdki4WC-kozzkFVoljzXQfA
# 26  UUguUR7CobZWf3n6enaEGZqA
# 27  UUPtPyb4VvaNqjkbL_tSVFVA
# 28  UU5c9VlYTSvBSCaoMu_GI6gQ

# %%
channel_data.to_excel("totalviews.xlsx",index=False)

# %%
# Convert count columns to numeric columns
numeric_cols = ['subscribers', 'views', 'totalVideos']
channel_data[numeric_cols] = channel_data[numeric_cols].apply(pd.to_numeric, errors='coerce')

# %%
def get_channel_stats(youtube, channel_ids):
   
    all_data = []
    request = youtube.channels().list(
                part='snippet,contentDetails,statistics',
                id=','.join(channel_ids))
    response = request.execute() 
    
    for i in range(len(response['items'])):
        data = dict(channelName = response['items'][i]['snippet']['title'],
                    subscribers = response['items'][i]['statistics']['subscriberCount'],
                    views = response['items'][i]['statistics']['viewCount'],
                    totalVideos = response['items'][i]['statistics']['videoCount'],
                    playlistId = response['items'][i]['contentDetails']['relatedPlaylists']['uploads'])
        all_data.append(data)
    
    return pd.DataFrame(all_data)

def get_video_ids(youtube, playlist_id):
    
    
    request = youtube.playlistItems().list(
                part='contentDetails',
                playlistId = playlist_id,
                maxResults = 50)
    response = request.execute()
    
    video_ids = []
    
    for i in range(len(response['items'])):
        video_ids.append(response['items'][i]['contentDetails']['videoId'])
        
    next_page_token = response.get('nextPageToken')
    more_pages = True
    
    while more_pages:
        if next_page_token is None:
            more_pages = False
        else:
            request = youtube.playlistItems().list(
                        part='contentDetails',
                        playlistId = playlist_id,
                        maxResults = 50,
                        pageToken = next_page_token)
            response = request.execute()
    
            for i in range(len(response['items'])):
                video_ids.append(response['items'][i]['contentDetails']['videoId'])
            
            next_page_token = response.get('nextPageToken')
        
    return video_ids

def get_video_details(youtube, video_ids):
    
        
    all_video_info = []
    
    for i in range(0, len(video_ids), 50):
        request = youtube.videos().list(
            part="snippet,contentDetails,statistics",
            id=','.join(video_ids[i:i+50])
        )
        response = request.execute() 

        for video in response['items']:
            stats_to_keep = {'snippet': ['channelName', 'title', 'description', 'tags', 'publishedAt'],
                             'statistics': ['viewCount', 'likeCount', 'favouriteCount', 'commentCount'],
                             'contentDetails': ['duration', 'definition', 'caption']
                            }
            video_info = {}
            video_info['video_id'] = video['id']

            for k in stats_to_keep.keys():
                for v in stats_to_keep[k]:
                    try:
                        video_info[v] = video[k][v]
                    except:
                        video_info[v] = None

            all_video_info.append(video_info)
            
    return pd.DataFrame(all_video_info)

# %%
# Create a dataframe with video statistics and comments from all channels

video_df = pd.DataFrame()

for c in channel_data['channelName'].unique():
    print("Getting video information from channel: " + c)
    playlist_id = channel_data.loc[channel_data['channelName']== c, 'playlistId'].iloc[0]
    video_ids = get_video_ids(youtube, playlist_id)
    
    # get video data
    video_data = get_video_details(youtube, video_ids)
    
    video_df = pd.concat([video_df, video_data], ignore_index=True)
# Out:
# Getting video information from channel: Shivam Trivedi
# Getting video information from channel: Tanmay Bhat
# Getting video information from channel: TechWiser
# Getting video information from channel: Gaurav Thakur
# Getting video information from channel: Manoj Saru
# Getting video information from channel: Physics Wallah - Alakh Pandey
# Getting video information from channel: CodeWithHarry
# Getting video information from channel: Deepti Lakhwani
# Getting video information from channel: shreeman legend live
# Getting video information from channel: Simple History
# Getting video information from channel: Rock 'N Learn
# Getting video information from channel: Mythpat
# Getting video information from channel: Samay Raina
# Getting video information from channel: A4
# Getting video information from channel: PewDiePie
# Getting video information from channel: Abhipsa Joshi
# Getting video information from channel: Vidhi Rajput
# Getting video information from channel: Engineer Reveals
# Getting video information from channel: TechBar
# Getting video information from channel: Abhi and Niyu
# Getting video information from channel: Triggered Insaan
# Getting video information from channel: AKTK
# Getting video information from channel: Way to Success
# Getting video information from channel: Gaurav Chaudhary
# Getting video information from channel: The Sham Sharma Show
# Getting video information from channel: Mishti Pandey
# Getting video information from channel: Style&Dine
# Getting video information from channel: Thugesh
# Getting video information from channel: Total Gaming

# %%
video_df
# Out:
#           video_id channelName  \
# 0      DIcYS_VW_F0        None
# 1      lQ5jiyLykhg        None
# 2      akhB87ErYgQ        None
# 3      aaM5QT3-_OQ        None
# 4      psyJu7iWVfs        None
# ...            ...         ...
# 28899  RVQ-yCtfUVk        None
# 28900  lYD1xP7Az2k        None
# 28901  sie3rWeD8C0        None
# 28902  XQ7EA3t0cOQ        None
# 28903  YM9oGDhbrtU        None
#
#                                                    title  \
# 0      Anant Ambani's Shaadi Madness is SO FUNNY!😂 | ...
# 1      India’s Worst Shaadi Vlogger!😂 | Raja Vlogs Roast
# 2      SHARK TANK INDIA 3 IS A JOKE!🤦🏻‍♂️😂 | Roast Re...
# 3      These Food videos are WORSE than Poonam Pandey...
# 4               Things I learnt from BB17😂 #shorts #BB17
# ...                                                  ...
# 28899  Solo vs Squad Famas Master 17 Kills Gameplay -...
# 28900  Free Fire Tips and Tricks in Hindi - 3 Day To ...
# 28901  How To Get Free Diamonds In Free Fire 2019 - R...
# 28902  I Meet Wall Hacker In Free Fire, Speed Hack, C...
# 28903  Free Fire : EPIC WIN! Total 24 Kills SQUAD Mat...
#
#                                              description  \
# 0      Hope you Liked this video, Make sure to share ...
# 1      Hope you Liked this video, Make sure to share ...
# 2      Hope you Liked this video, Make sure to share ...
# 3      Get ready for the ultimate showdown as we dive...
# 4
# ...                                                  ...
# 28899  📷 Instagram: https://www.instagram.com/totalga...
# 28900  📷 Instagram: https://www.instagram.com/totalga...
# 28901  How To Get Free Diamonds In Free Fire Without ...
# 28902  📷 Instagram: https://www.instagram.com/totalga...
# 28903  Garena Free Fire Best Gameplay. Try To Make Pe...
#
#                                                     tags  \
# 0      [shivam, trivedi, thinks, shivam trivedi, roas...
# 1      [shivam, trivedi, thinks, shivam trivedi, roas...
# 2      [shivam, trivedi, thinks, shivam trivedi, roas...
# 3      [shivam, trivedi, thinks, shivam trivedi, roas...
# 4                                                   None
# ...                                                  ...
# 28899  [Free fire, Garena Free fire, Free Fire Live, ...
# 28900  [Garena Free Fire, Free Fire, Total Gaming, Fr...
# 28901  [Garena Free Fire, Free Fire, Total Gaming, Fr...
# 28902        [Garena Free Fire, Free fire, Total Gaming]
# 28903  [Free fire best gamplay, free fire indian best...
#
#                 publishedAt viewCount likeCount favouriteCount commentCount  \
# 0      2024-03-11T17:21:39Z    112506      7261           None          137
# 1      2024-02-29T16:41:28Z    168238      8083           None          316
# 2      2024-02-23T16:33:37Z    161216      9731           None          235
# 3      2024-02-05T16:15:33Z    105437      7417           None          146
# 4      2024-01-28T17:08:16Z     16838      1531           None           28
# ...                     ...       ...       ...            ...          ...
# 28899  2019-08-12T12:58:52Z   7107537    566075           None         6788
# 28900  2019-08-07T13:43:35Z   6481166    443888           None         9436
# 28901  2019-07-26T14:18:20Z   4526903    270173           None        14433
# 28902  2019-07-22T12:29:03Z   9876933    463079           None         8092
# 28903  2018-12-02T10:10:16Z   3460896    272059           None        22218
#
#        duration definition caption
# 0      PT10M16S         hd   false
# 1       PT9M54S         hd   false
# 2      PT11M37S         hd   false
# 3      PT11M16S         hd   false
# 4         PT22S         hd   false
# ...         ...        ...     ...
# 28899  PT16M43S         hd   false
# 28900  PT10M27S         hd   false
# 28901  PT10M14S         hd   false
# 28902  PT11M58S         hd   false
# 28903   PT6M58S         hd   false
#
# [28904 rows x 13 columns]

# %% [markdown]
# # Dataprocessing

# %%
video_df.dtypes
# Out:
# video_id          object
# channelName       object
# title             object
# description       object
# tags              object
# publishedAt       object
# viewCount         object
# likeCount         object
# favouriteCount    object
# commentCount      object
# duration          object
# definition        object
# caption           object
# dtype: object

# %%
video_df.publishedAt.sort_values().value_counts()
# Out:
# publishedAt
# 2018-01-11T15:52:18Z    11
# 2016-01-30T16:36:26Z     3
# 2016-01-30T16:36:27Z     3
# 2022-10-27T14:30:10Z     2
# 2021-02-21T11:30:00Z     2
#                         ..
# 2019-12-25T13:53:15Z     1
# 2019-12-25T13:00:07Z     1
# 2019-12-25T12:30:11Z     1
# 2019-12-25T10:22:00Z     1
# 2024-03-21T06:36:41Z     1
# Name: count, Length: 28856, dtype: int64

# %%
video_df.isnull().sum()
# Out:
# video_id              0
# channelName       28904
# title                 0
# description           0
# tags               5581
# publishedAt           0
# viewCount            10
# likeCount            33
# favouriteCount    28904
# commentCount        148
# duration              0
# definition            0
# caption               0
# dtype: int64

# %%
cols = ['viewCount', 'likeCount', 'favouriteCount', 'commentCount']
video_df[cols] = video_df[cols].apply(pd.to_numeric, errors='coerce', axis=1)

# %%
columns_to_drop = ['favouriteCount']
video_df = video_df.drop(columns_to_drop, axis=1)

# %%
# Publish day in the week
video_df['published_Date'] = pd.to_datetime(video_df['publishedAt']).dt.date
video_df['published_Date']
# Out:
# 0        2024-03-11
# 1        2024-02-29
# 2        2024-02-23
# 3        2024-02-05
# 4        2024-01-28
#             ...
# 28899    2019-08-12
# 28900    2019-08-07
# 28901    2019-07-26
# 28902    2019-07-22
# 28903    2018-12-02
# Name: published_Date, Length: 28904, dtype: object

# %%
# convert duration to seconds
video_df['durationSecs'] = pd.to_timedelta(video_df['duration']).dt.total_seconds()
video_df[['durationSecs', 'duration']]
# Out:
#        durationSecs  duration
# 0             616.0  PT10M16S
# 1             594.0   PT9M54S
# 2             697.0  PT11M37S
# 3             676.0  PT11M16S
# 4              22.0     PT22S
# ...             ...       ...
# 28899        1003.0  PT16M43S
# 28900         627.0  PT10M27S
# 28901         614.0  PT10M14S
# 28902         718.0  PT11M58S
# 28903         418.0   PT6M58S
#
# [28904 rows x 2 columns]

# %%
## Add number of tags
null_tags = video_df[video_df["tags"].isnull()].index
video_df.drop(null_tags,inplace=True)

# %%
video_df.description.isnull().sum()
# Out:
# 0

# %%
null_description = video_df[video_df["description"].isnull()].index
null_description
# Out:
# Index([], dtype='int64')

# %%
video_df.drop(null_description,inplace=True)

# %%
video_df = video_df.drop(['publishedAt'], axis=1)

# %%
video_df.head()
# Out:
#       video_id channelName                                              title  \
# 0  DIcYS_VW_F0        None  Anant Ambani's Shaadi Madness is SO FUNNY!😂 | ...
# 1  lQ5jiyLykhg        None  India’s Worst Shaadi Vlogger!😂 | Raja Vlogs Roast
# 2  akhB87ErYgQ        None  SHARK TANK INDIA 3 IS A JOKE!🤦🏻‍♂️😂 | Roast Re...
# 3  aaM5QT3-_OQ        None  These Food videos are WORSE than Poonam Pandey...
# 5  sLG1n5TrFlE        None  Orry on Koffee with Karan is the WORST COMBO E...
#
#                                          description  \
# 0  Hope you Liked this video, Make sure to share ...
# 1  Hope you Liked this video, Make sure to share ...
# 2  Hope you Liked this video, Make sure to share ...
# 3  Get ready for the ultimate showdown as we dive...
# 5  Jiss Astrologer se maine apne 2024 ke baare ma...
#
#                                                 tags  viewCount  likeCount  \
# 0  [shivam, trivedi, thinks, shivam trivedi, roas...   112506.0     7261.0
# 1  [shivam, trivedi, thinks, shivam trivedi, roas...   168238.0     8083.0
# 2  [shivam, trivedi, thinks, shivam trivedi, roas...   161216.0     9731.0
# 3  [shivam, trivedi, thinks, shivam trivedi, roas...   105437.0     7417.0
# 5  [shivam, trivedi, thinks, shivam trivedi, roas...   161241.0     8516.0
#
#    commentCount  duration definition caption published_Date  durationSecs
# 0         137.0  PT10M16S         hd   false     2024-03-11         616.0
# 1         316.0   PT9M54S         hd   false     2024-02-29         594.0
# 2         235.0  PT11M37S         hd   false     2024-02-23         697.0
# 3         146.0  PT11M16S         hd   false     2024-02-05         676.0
# 5         176.0  PT10M41S         hd   false     2024-01-24         641.0
